# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import KFold
from sklearn import model_selection
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold
import statistics 
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_excel('DB1.xlsx', index_col=None, header=6)

# %%
################## 1. Hinterschnitt #######################

print ('-----------------Hinterschnitt----------------')
print('\n')
X = df[['Materialsorte_OB','Materialsorte_UB','Zugfestigkeit_OB','Zugfestigkeit_UB','Dicke_OB','Dicke_UB','Niettyp','Nietlaenge','Matrizendurchmesser','Matrizentiefe','Dornhoehe','Dornbreite','Konturradius','Nietkopfendlage']]
Y = df['Hinterschnitt']

X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size=0.2, random_state=0)

regressor= linear_model.LinearRegression()
model=regressor.fit(X_train, Y_train)
#result = model.score(X_test,Y_test)
y_pred=regressor.predict(X_test)
Hinterschnitt_r2=r2_score(Y_test, y_pred)
coef = pd.DataFrame(regressor.coef_, X_train.columns, columns = ['Coefficients'])
print(coef)

print('Intercept: ',regressor.intercept_)
print("R2 without kfold: " ,Hinterschnitt_r2) 


error_model=[]

kfold = KFold(n_splits=10, random_state=0)
# results_kfold = model_selection.cross_val_score(model, X, Y, cv=kfold)
# print(results_kfold)
# print("Accuracy: %.2f%%" % (results_kfold.mean()*100.0)) 

for train_index, test_index in kfold.split(X):
#     print("TRAIN:", train_index, "TEST:", test_index)
    X_train_k, X_test_k = X.iloc[train_index], X.iloc[test_index]
    Y_train_k, Y_test_k = Y.iloc[train_index], Y.iloc[test_index]
    regresso_kr= linear_model.LinearRegression()
    model_k=regressor.fit(X_train_k, Y_train_k)
    y_pred_k=regressor.predict(X_test_k)
    error_model.append(r2_score(Y_test_k, y_pred_k))

Hinterschnitt_R2_kfold=sum(error_model)/10
print('R2 with kfold:',Hinterschnitt_R2_kfold)


print('\n')
print('-------------------------------------')
X_endog = sm.add_constant(X_train.values)
res = sm.OLS(Y_train, X_endog).fit()
print(res.summary())
# Out:
# -----------------Hinterschnitt----------------
#
#
#                      Coefficients
# Materialsorte_OB         0.000753
# Materialsorte_UB         0.040681
# Zugfestigkeit_OB         0.000060
# Zugfestigkeit_UB        -0.000315
# Dicke_OB                -0.245148
# Dicke_UB                 0.185880
# Niettyp                 -0.122728
# Nietlaenge               0.234494
# Matrizendurchmesser     -0.106991
# Matrizentiefe           -0.122616
# Dornhoehe               -0.070602
# Dornbreite               0.012593
# Konturradius            -0.009876
# Nietkopfendlage         -0.033650
# Intercept:  0.6415034225911876
# R2 without kfold:  0.7514254737846443
# R2 with kfold: 0.5246300169806616
#
#
# -------------------------------------
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Hinterschnitt   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.614
# Method:                 Least Squares   F-statistic:                     13.11
# Date:                Wed, 08 Jul 2020   Prob (F-statistic):           2.20e-15
# Time:                        12:42:03   Log-Likelihood:                 99.561
# No. Observations:                 100   AIC:                            -171.1
# Df Residuals:                      86   BIC:                            -134.6
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5152      0.255      2.024      0.046       0.009       1.021
# x1             0.0008      0.028      0.026      0.979      -0.056       0.057
# x2             0.0407      0.026      1.575      0.119      -0.011       0.092
# x3          6.012e-05   5.94e-05      1.012      0.315    -5.8e-05       0.000
# x4            -0.0003   8.12e-05     -3.885      0.000      -0.000      -0.000
# x5            -0.2451      0.056     -4.413      0.000      -0.356      -0.135
# x6             0.1859      0.048      3.889      0.000       0.091       0.281
# x7            -0.1227      0.034     -3.565      0.001      -0.191      -0.054
# x8             0.2345      0.039      6.039      0.000       0.157       0.312
# x9            -0.1070      0.031     -3.501      0.001      -0.168      -0.046
# x10           -0.1226      0.064     -1.906      0.060      -0.251       0.005
# x11           -0.1058      0.072     -1.466      0.146      -0.249       0.038
# x12            0.0133      0.019      0.689      0.492      -0.025       0.052
# x13            0.2428      0.120      2.019      0.047       0.004       0.482
# x14           -0.0336      0.017     -1.962      0.053      -0.068       0.000
# ==============================================================================
# Omnibus:                        1.915   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.384   Jarque-Bera (JB):                1.358
# Skew:                           0.160   Prob(JB):                        0.507
# Kurtosis:                       3.472   Cond. No.                     2.68e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.47e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
################## 2. min_Materialdicke_UB #######################

print ('-----------------min_Materialdicke_UB----------------')
print('\n')
X = df[['Materialsorte_OB','Materialsorte_UB','Zugfestigkeit_OB','Zugfestigkeit_UB','Dicke_OB','Dicke_UB','Niettyp','Nietlaenge','Matrizendurchmesser','Matrizentiefe','Dornhoehe','Dornbreite','Konturradius','Nietkopfendlage']]
Y = df['min_Materialdicke_UB']

X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size=0.2, random_state=0)

regressor= linear_model.LinearRegression()
model=regressor.fit(X_train, Y_train)
#result = model.score(X_test,Y_test)
y_pred=regressor.predict(X_test)
min_Materialdicke_UB_r2=r2_score(Y_test, y_pred)
coef = pd.DataFrame(regressor.coef_, X_train.columns, columns = ['Coefficients'])
print(coef)
print('Intercept: ',regressor.intercept_)
print("R2 without kfold: " ,min_Materialdicke_UB_r2) 


error_model=[]

kfold = KFold(n_splits=10, random_state=0)
# results_kfold = model_selection.cross_val_score(model, X, Y, cv=kfold)
# print(results_kfold)
# print("Accuracy: %.2f%%" % (results_kfold.mean()*100.0)) 

for train_index, test_index in kfold.split(X):
#     print("TRAIN:", train_index, "TEST:", test_index)
    X_train_k, X_test_k = X.iloc[train_index], X.iloc[test_index]
    Y_train_k, Y_test_k = Y.iloc[train_index], Y.iloc[test_index]
    regresso_kr= linear_model.LinearRegression()
    model_k=regressor.fit(X_train_k, Y_train_k)
    y_pred_k=regressor.predict(X_test_k)
    error_model.append(r2_score(Y_test_k, y_pred_k))
min_Materialdicke_UB_R2_kfold=sum(error_model)/10
print('R2 with kfold:',min_Materialdicke_UB_R2_kfold)


print('\n')
print('-------------------------------------')
X_endog = sm.add_constant(X_train.values)
res = sm.OLS(Y_train, X_endog).fit()
print(res.summary())
# Out:
# -----------------min_Materialdicke_UB----------------
#
#
#                      Coefficients
# Materialsorte_OB        -0.123559
# Materialsorte_UB        -0.090520
# Zugfestigkeit_OB         0.000270
# Zugfestigkeit_UB         0.000504
# Dicke_OB                 0.421461
# Dicke_UB                 0.550899
# Niettyp                 -0.205859
# Nietlaenge              -0.194431
# Matrizendurchmesser     -0.025523
# Matrizentiefe           -0.014507
# Dornhoehe                0.167574
# Dornbreite              -0.020207
# Konturradius             0.023416
# Nietkopfendlage          0.014717
# Intercept:  0.414227266286323
# R2 without kfold:  0.3839414448924836
# R2 with kfold: 0.3666480817190453
#
#
# -------------------------------------
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     min_Materialdicke_UB   R-squared:                       0.781
# Model:                              OLS   Adj. R-squared:                  0.748
# Method:                   Least Squares   F-statistic:                     23.56
# Date:                  Wed, 08 Jul 2020   Prob (F-statistic):           5.99e-23
# Time:                          12:42:03   Log-Likelihood:                 94.159
# No. Observations:                   100   AIC:                            -160.3
# Df Residuals:                        86   BIC:                            -123.8
# Df Model:                            13
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3327      0.269      1.238      0.219      -0.201       0.867
# x1            -0.1236      0.030     -4.115      0.000      -0.183      -0.064
# x2            -0.0905      0.027     -3.321      0.001      -0.145      -0.036
# x3             0.0003   6.27e-05      4.306      0.000       0.000       0.000
# x4             0.0005   8.57e-05      5.888      0.000       0.000       0.001
# x5             0.4215      0.059      7.189      0.000       0.305       0.538
# x6             0.5509      0.050     10.919      0.000       0.451       0.651
# x7            -0.2059      0.036     -5.666      0.000      -0.278      -0.134
# x8            -0.1944      0.041     -4.744      0.000      -0.276      -0.113
# x9            -0.0255      0.032     -0.791      0.431      -0.090       0.039
# x10           -0.0145      0.068     -0.214      0.831      -0.149       0.120
# x11            0.1448      0.076      1.901      0.061      -0.007       0.296
# x12           -0.0198      0.020     -0.973      0.333      -0.060       0.021
# x13            0.1866      0.127      1.470      0.145      -0.066       0.439
# x14            0.0147      0.018      0.813      0.418      -0.021       0.051
# ==============================================================================
# Omnibus:                        9.395   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                9.223
# Skew:                           0.673   Prob(JB):                      0.00994
# Kurtosis:                       3.636   Cond. No.                     2.68e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.47e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
################## 3. Hinterschnitthoehe #######################

print ('-----------------Hinterschnitthoehe----------------')
print('\n')
X = df[['Materialsorte_OB','Materialsorte_UB','Zugfestigkeit_OB','Zugfestigkeit_UB','Dicke_OB','Dicke_UB','Niettyp','Nietlaenge','Matrizendurchmesser','Matrizentiefe','Dornhoehe','Dornbreite','Konturradius','Nietkopfendlage']]
Y = df['Hinterschnitthoehe']

X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size=0.2, random_state=0)

regressor= linear_model.LinearRegression()
model=regressor.fit(X_train, Y_train)
#result = model.score(X_test,Y_test)
y_pred=regressor.predict(X_test)
Hinterschnitthoehe_r2=r2_score(Y_test, y_pred)
coef = pd.DataFrame(regressor.coef_, X_train.columns, columns = ['Coefficients'])
print(coef)
print('Intercept: ',regressor.intercept_)
print("R2 without kfold: " ,Hinterschnitthoehe_r2) 


error_model=[]

kfold = KFold(n_splits=10, random_state=0)
# results_kfold = model_selection.cross_val_score(model, X, Y, cv=kfold)
# print(results_kfold)
# print("Accuracy: %.2f%%" % (results_kfold.mean()*100.0)) 

for train_index, test_index in kfold.split(X):
#     print("TRAIN:", train_index, "TEST:", test_index)
    X_train_k, X_test_k = X.iloc[train_index], X.iloc[test_index]
    Y_train_k, Y_test_k = Y.iloc[train_index], Y.iloc[test_index]
    regresso_kr= linear_model.LinearRegression()
    model_k=regressor.fit(X_train_k, Y_train_k)
    y_pred_k=regressor.predict(X_test_k)
    error_model.append(r2_score(Y_test_k, y_pred_k))
Hinterschnitthoehe_R2_kfold=sum(error_model)/10
print('R2 with kfold:',Hinterschnitthoehe_R2_kfold)


print('\n')
print('-------------------------------------')
X_endog = sm.add_constant(X_train.values)
res = sm.OLS(Y_train, X_endog).fit()
print(res.summary())
# Out:
# -----------------Hinterschnitthoehe----------------
#
#
#                      Coefficients
# Materialsorte_OB         0.107504
# Materialsorte_UB         0.144448
# Zugfestigkeit_OB        -0.000029
# Zugfestigkeit_UB        -0.000083
# Dicke_OB                -0.476514
# Dicke_UB                 0.527613
# Niettyp                 -0.035067
# Nietlaenge               0.276606
# Matrizendurchmesser     -0.120983
# Matrizentiefe            0.089986
# Dornhoehe               -0.175426
# Dornbreite               0.044795
# Konturradius            -0.024576
# Nietkopfendlage         -0.010169
# Intercept:  0.03779328317114328
# R2 without kfold:  0.8213682942645625
# R2 with kfold: 0.6555380567168718
#
#
# -------------------------------------
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Hinterschnitthoehe   R-squared:                       0.784
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     23.96
# Date:                Wed, 08 Jul 2020   Prob (F-statistic):           3.50e-23
# Time:                        12:42:04   Log-Likelihood:                 54.050
# No. Observations:                 100   AIC:                            -80.10
# Df Residuals:                      86   BIC:                            -43.63
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0304      0.401      0.076      0.940      -0.767       0.828
# x1             0.1075      0.045      2.397      0.019       0.018       0.197
# x2             0.1444      0.041      3.548      0.001       0.064       0.225
# x3         -2.863e-05   9.37e-05     -0.306      0.761      -0.000       0.000
# x4         -8.345e-05      0.000     -0.652      0.516      -0.000       0.000
# x5            -0.4765      0.088     -5.442      0.000      -0.651      -0.302
# x6             0.5276      0.075      7.002      0.000       0.378       0.677
# x7            -0.0351      0.054     -0.646      0.520      -0.143       0.073
# x8             0.2766      0.061      4.519      0.000       0.155       0.398
# x9            -0.1210      0.048     -2.511      0.014      -0.217      -0.025
# x10            0.0900      0.101      0.887      0.377      -0.112       0.292
# x11           -0.1775      0.114     -1.560      0.122      -0.404       0.049
# x12            0.0448      0.030      1.477      0.143      -0.015       0.105
# x13           -0.0097      0.190     -0.051      0.959      -0.386       0.367
# x14           -0.0102      0.027     -0.376      0.708      -0.064       0.044
# ==============================================================================
# Omnibus:                       12.467   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               28.526
# Skew:                          -0.352   Prob(JB):                     6.39e-07
# Kurtosis:                       5.520   Cond. No.                     2.68e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.47e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
################## 4. Nietfussdurchmesser #######################

print ('-----------------Nietfussdurchmesser----------------')
print('\n')
X = df[['Materialsorte_OB','Materialsorte_UB','Zugfestigkeit_OB','Zugfestigkeit_UB','Dicke_OB','Dicke_UB','Niettyp','Nietlaenge','Matrizendurchmesser','Matrizentiefe','Dornhoehe','Dornbreite','Konturradius','Nietkopfendlage']]
Y = df['Nietfussdurchmesser']

X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size=0.2, random_state=0)

regressor= linear_model.LinearRegression()
model=regressor.fit(X_train, Y_train)
#result = model.score(X_test,Y_test)
y_pred=regressor.predict(X_test)
Nietfussdurchmesser_r2=r2_score(Y_test, y_pred)
coef = pd.DataFrame(regressor.coef_, X_train.columns, columns = ['Coefficients'])
print(coef)
print('Intercept: ',regressor.intercept_)
print("R2 without kfold: " ,Nietfussdurchmesser_r2) 


error_model=[]

kfold = KFold(n_splits=10, random_state=0)
# results_kfold = model_selection.cross_val_score(model, X, Y, cv=kfold)
# print(results_kfold)
# print("Accuracy: %.2f%%" % (results_kfold.mean()*100.0)) 

for train_index, test_index in kfold.split(X):
#     print("TRAIN:", train_index, "TEST:", test_index)
    X_train_k, X_test_k = X.iloc[train_index], X.iloc[test_index]
    Y_train_k, Y_test_k = Y.iloc[train_index], Y.iloc[test_index]
    regresso_kr= linear_model.LinearRegression()
    model_k=regressor.fit(X_train_k, Y_train_k)
    y_pred_k=regressor.predict(X_test_k)
    error_model.append(r2_score(Y_test_k, y_pred_k))
Nietfussdurchmesser_R2_kfold=sum(error_model)/10
print('R2 with kfold:',Nietfussdurchmesser_R2_kfold)


print('\n')
print('-------------------------------------')
X_endog = sm.add_constant(X_train.values)
res = sm.OLS(Y_train, X_endog).fit()
print(res.summary())
# Out:
# -----------------Nietfussdurchmesser----------------
#
#
#                      Coefficients
# Materialsorte_OB        -0.242702
# Materialsorte_UB        -0.022855
# Zugfestigkeit_OB         0.000479
# Zugfestigkeit_UB        -0.000578
# Dicke_OB                -0.315805
# Dicke_UB                -0.778326
# Niettyp                 -0.329156
# Nietlaenge               0.621690
# Matrizendurchmesser      0.190166
# Matrizentiefe           -0.655182
# Dornhoehe                0.591364
# Dornbreite              -0.159386
# Konturradius             0.082869
# Nietkopfendlage         -0.014571
# Intercept:  5.469711677370106
# R2 without kfold:  0.659682950463748
# R2 with kfold: -1.171126910220066
#
#
# -------------------------------------
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Nietfussdurchmesser   R-squared:                       0.673
# Model:                             OLS   Adj. R-squared:                  0.624
# Method:                  Least Squares   F-statistic:                     13.64
# Date:                 Wed, 08 Jul 2020   Prob (F-statistic):           7.66e-16
# Time:                         12:42:04   Log-Likelihood:                -9.2023
# No. Observations:                  100   AIC:                             46.40
# Df Residuals:                       86   BIC:                             82.88
# Df Model:                           13
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.3925      0.755      5.817      0.000       2.891       5.894
# x1            -0.2427      0.084     -2.875      0.005      -0.411      -0.075
# x2            -0.0229      0.077     -0.298      0.766      -0.175       0.129
# x3             0.0005      0.000      2.719      0.008       0.000       0.001
# x4            -0.0006      0.000     -2.399      0.019      -0.001    -9.9e-05
# x5            -0.3158      0.165     -1.916      0.059      -0.643       0.012
# x6            -0.7783      0.142     -5.488      0.000      -1.060      -0.496
# x7            -0.3292      0.102     -3.222      0.002      -0.532      -0.126
# x8             0.6217      0.115      5.396      0.000       0.393       0.851
# x9             0.1902      0.091      2.097      0.039       0.010       0.370
# x10           -0.6552      0.191     -3.432      0.001      -1.035      -0.276
# x11            0.2910      0.214      1.359      0.178      -0.135       0.717
# x12           -0.1536      0.057     -2.689      0.009      -0.267      -0.040
# x13            2.2372      0.357      6.271      0.000       1.528       2.946
# x14           -0.0146      0.051     -0.286      0.775      -0.116       0.087
# ==============================================================================
# Omnibus:                       20.273   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.282
# Skew:                          -0.754   Prob(JB):                     6.58e-10
# Kurtosis:                       5.806   Cond. No.                     2.68e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.47e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
################## 4. Fuegekraft #######################

print ('-----------------Fuegekraft----------------')
print('\n')
X = df[['Materialsorte_OB','Materialsorte_UB','Zugfestigkeit_OB','Zugfestigkeit_UB','Dicke_OB','Dicke_UB','Niettyp','Nietlaenge','Matrizendurchmesser','Matrizentiefe','Dornhoehe','Dornbreite','Konturradius','Nietkopfendlage']]
Y = df['Fuegekraft']

X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size=0.2, random_state=0)

regressor= linear_model.LinearRegression()
model=regressor.fit(X_train, Y_train)
#result = model.score(X_test,Y_test)
y_pred=regressor.predict(X_test)
Fuegekraft_r2=r2_score(Y_test, y_pred)
coef = pd.DataFrame(regressor.coef_, X_train.columns, columns = ['Coefficients'])
print(coef)
print('Intercept: ',regressor.intercept_)
print("R2 without kfold: " ,Fuegekraft_r2) 


error_model=[]

kfold = KFold(n_splits=10, random_state=0)
# results_kfold = model_selection.cross_val_score(model, X, Y, cv=kfold)
# print(results_kfold)
# print("Accuracy: %.2f%%" % (results_kfold.mean()*100.0)) 

for train_index, test_index in kfold.split(X):
#     print("TRAIN:", train_index, "TEST:", test_index)
    X_train_k, X_test_k = X.iloc[train_index], X.iloc[test_index]
    Y_train_k, Y_test_k = Y.iloc[train_index], Y.iloc[test_index]
    regresso_kr= linear_model.LinearRegression()
    model_k=regressor.fit(X_train_k, Y_train_k)
    y_pred_k=regressor.predict(X_test_k)
    error_model.append(r2_score(Y_test_k, y_pred_k))
Fuegekraft_R2_kfold=sum(error_model)/10
print('R2 with kfold:',Fuegekraft_R2_kfold)


print('\n')
print('-------------------------------------')
X_endog = sm.add_constant(X_train.values)
res = sm.OLS(Y_train, X_endog).fit()
print(res.summary())
# Out:
# -----------------Fuegekraft----------------
#
#
#                      Coefficients
# Materialsorte_OB        -3.466700
# Materialsorte_UB        -3.679286
# Zugfestigkeit_OB         0.000227
# Zugfestigkeit_UB         0.014809
# Dicke_OB                 4.767181
# Dicke_UB                 1.907464
# Niettyp                  7.311555
# Nietlaenge               2.758245
# Matrizendurchmesser     -2.553048
# Matrizentiefe          -20.929842
# Dornhoehe                2.155882
# Dornbreite              -0.303965
# Konturradius             0.301367
# Nietkopfendlage         -0.236525
# Intercept:  83.03194222191934
# R2 without kfold:  0.6096302711271767
# R2 with kfold: -18.48465600644577
#
#
# -------------------------------------
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Fuegekraft   R-squared:                       0.468
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     5.813
# Date:                Wed, 08 Jul 2020   Prob (F-statistic):           1.48e-07
# Time:                        12:42:04   Log-Likelihood:                -313.01
# No. Observations:                 100   AIC:                             654.0
# Df Residuals:                      86   BIC:                             690.5
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         66.6799     15.757      4.232      0.000      35.355      98.004
# x1            -3.4667      1.761     -1.968      0.052      -6.968       0.035
# x2            -3.6793      1.599     -2.301      0.024      -6.858      -0.501
# x3             0.0002      0.004      0.062      0.951      -0.007       0.008
# x4             0.0148      0.005      2.947      0.004       0.005       0.025
# x5             4.7672      3.439      1.386      0.169      -2.069      11.604
# x6             1.9075      2.959      0.645      0.521      -3.976       7.791
# x7             7.3116      2.131      3.431      0.001       3.075      11.548
# x8             2.7582      2.404      1.147      0.254      -2.021       7.537
# x9            -2.5530      1.892     -1.349      0.181      -6.314       1.208
# x10          -20.9298      3.983     -5.255      0.000     -28.848     -13.012
# x11           -2.4034      4.469     -0.538      0.592     -11.287       6.480
# x12           -0.2163      1.192     -0.181      0.856      -2.586       2.153
# x13           33.0055      7.444      4.434      0.000      18.207      47.804
# x14           -0.2365      1.062     -0.223      0.824      -2.347       1.874
# ==============================================================================
# Omnibus:                        1.607   Durbin-Watson:                   1.825
# Prob(Omnibus):                  0.448   Jarque-Bera (JB):                1.354
# Skew:                           0.285   Prob(JB):                        0.508
# Kurtosis:                       3.012   Cond. No.                     2.68e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.47e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
avg_error=(Hinterschnitt_r2+min_Materialdicke_UB_r2+Hinterschnitthoehe_r2+Nietfussdurchmesser_r2+Fuegekraft_r2)/5
print('Average error without kfold: ',avg_error)
avg_error_kfold=(Hinterschnitt_R2_kfold +min_Materialdicke_UB_R2_kfold+Hinterschnitthoehe_R2_kfold+Nietfussdurchmesser_R2_kfold+Fuegekraft_R2_kfold)/5
print('Average error with kfold: ',avg_error_kfold)
# Out:
# Average error without kfold:  0.6452096869065231
# Average error with kfold:  -3.6217933522498518
